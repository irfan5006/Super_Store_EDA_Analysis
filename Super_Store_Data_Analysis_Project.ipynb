# %% [markdown]
# # Project Name: __`🏨 Super-Store Revenue Accelerator 🚀`__
#
# ## __Perspective: 📊 Market Insights and Revenue Growth 🏆__

# %% [markdown]
# ---
# # Auther Name : __`Muhammad Irfan`__
# Email : mi641033@gmail.com\
# Github : https://github.com/irfan5006\
# Linkedln :https://www.linkedin.com/in/muhammad-irfan-a15359247
#
# ----

# %% [markdown]
# ## __`Dataset Description 📊`__
#
# - 📅 Order Date: Date when the order was placed.
# - 📋 Order ID: Unique identification number for each sales order.
# - 👤 Customer ID: Unique identifier for each customer.
# - 🧾 Product ID: Unique identifier for each product.
# - 📦 Quantity: Number of products ordered.
# - 💰 Unit Price: Price of a single product unit.
# - 📈 Total Revenue: Total revenue generated by the order.
# - 🌐 Ship To Location: Destination of the order shipment.
# - 🚚 Shipping Method: Method used to deliver the order.
# - 📬 Payment Method: Payment method used for the transaction.
# - 🌟 Customer Rating: Customer satisfaction rating for the order.
# - 📦 Product Category: Category to which the product belongs.
# - 🏢 Store Location: Location of the store where the order was placed.
# - ⏰ Order Processing Time: Time taken to process the order.
# - ⏱️ Delivery Time: Time taken for the order to be delivered.
# - 🌏 Market Segment: Segment of the market where the order was made.
# - 🌆 City: City where the order was placed.
# - 🌍 Country: Country where the order was placed.

# %% [markdown]
# ## EDA (Exploratory Data Analysis) 📊

# %% [markdown]
# ## Step 1: Import necessary libraries and load the dataset

# %%
# Import Libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Set the Maximum Rows and Columns 
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# Igonre Warnings 
import warnings
warnings.filterwarnings('ignore')

# %%
# Load the Dataset using pandas 
df = pd.read_csv("E:\Data_Sacience\day_24\SuperStore_Sales_Dataset.csv")

# %% [markdown]
# ## Step 2: Data Overview

# %%
# Lets Get Peak Snapshot
df.head()
# Out:
#    Row ID+O6G3A1:R6        Order ID  Order Date   Ship Date       Ship Mode  \
# 0              4918  CA-2019-160304  01-01-2019  07-01-2019  Standard Class
# 1              4919  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 2              4920  CA-2019-160304  02-01-2019  07-01-2019  Standard Class
# 3              3074  CA-2019-125206  03-01-2019  05-01-2019     First Class
# 4              8604  US-2019-116365  03-01-2019  08-01-2019  Standard Class
#
#   Customer ID      Customer Name    Segment        Country          City  \
# 0    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg
# 1    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg
# 2    BM-11575      Brendan Murry  Corporate  United States  Gaithersburg
# 3    LR-16915       Lena Radford   Consumer  United States   Los Angeles
# 4    CA-12310  Christine Abelman  Corporate  United States   San Antonio
#
# ...

# %%
# Lets Check Now Information about dataset and dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5901 entries, 0 to 5900
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Row ID+O6G3A1:R6  5901 non-null   int64
#  1   Order ID          5901 non-null   object
#  2   Order Date        5901 non-null   object
#  3   Ship Date         5901 non-null   object
#  4   Ship Mode         5901 non-null   object
#  5   Customer ID       5901 non-null   object
#  6   Customer Name     5901 non-null   object
#  7   Segment           5901 non-null   object
#  8   Country           5901 non-null   object
#  9   City              5901 non-null   object
#  10  State             5901 non-null   object
#  11  Region            5901 non-null   object
#  12  Product ID        5901 non-null   object
#  13  Category          5901 non-null   object
#  14  Sub-Category      5901 non-null   object
#  15  Product Name      5901 non-null   object
# ...

# %% [markdown]
# ## Observation:
# 1. There is 23 columns and the columns `ind1 `and `ind2` Totally null first we drop this coloumns .
# 2. In Returns Columns only `287` values remaning `Nan` but on the Other hand its Good for Our Analysis we will not remove and Fill.

# %% [markdown]
# ## Step 3: Data Cleaning

# %%
df.drop(columns=['ind1','ind2'] , axis=1 , inplace = True)

# %%
# Check for missing values
missing_values = df.isnull().sum()
missing_values_sorted = missing_values.sort_values(ascending=False)
print(f"Missing values (sorted in descending order):\n{missing_values_sorted}")
# Out:
# Missing values (sorted in descending order):
# Returns             5614
# Row ID+O6G3A1:R6       0
# Region                 0
# Profit                 0
# Quantity               0
# Sales                  0
# Product Name           0
# Sub-Category           0
# Category               0
# Product ID             0
# State                  0
# Order ID               0
# City                   0
# Country                0
# Segment                0
# Customer Name          0
# Customer ID            0
# Ship Mode              0
# Ship Date              0
# Order Date             0
# Payment Mode           0
# dtype: int64

# %%
# Check for duplicates
duplicates = df.duplicated().sum()
print(f"There is {duplicates} No-duplicates Values.")
# Out:
# There is 0 No-duplicates Values.

# %%
# Change the Date Format.
df['Order Date'] = pd.to_datetime(df['Order Date'], format='%d-%m-%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format='%d-%m-%Y')

# %%
# Get Year From data Column and make New column
df['Year'] = df['Order Date'].dt.year

# %% [markdown]
# ## Step 4: Descriptive Statistics

# %%
# Get basic statistics for numerical columns
stats = df.describe()
stats
# Out:
#        Row ID+O6G3A1:R6                     Order Date  \
# count       5901.000000                           5901
# mean        5022.422471  2020-02-29 01:53:57.620742144
# min            1.000000            2019-01-01 00:00:00
# 25%         2486.000000            2019-09-11 00:00:00
# 50%         5091.000000            2020-03-16 00:00:00
# 75%         7456.000000            2020-09-14 00:00:00
# max         9994.000000            2020-12-31 00:00:00
# std         2877.977184                            NaN
#
#                            Ship Date        Sales     Quantity       Profit  \
# count                           5901  5901.000000  5901.000000  5901.000000
# mean   2020-03-04 00:08:47.097102336   265.345589     3.781901    29.700408
# min              2019-01-05 00:00:00     0.836000     1.000000 -6599.978000
# 25%              2019-09-15 00:00:00    71.976000     2.000000     1.795500
# 50%              2020-03-19 00:00:00   128.648000     3.000000     8.502500
# ...

# %% [markdown]
# ## Step 04 : Data Visualizations

# %%
# Set the style for the plot (optional)
sns.set_style("whitegrid")

# Create a scatter plot using Seaborn
plt.figure(figsize=(18, 6))
sns.scatterplot(data=df, x='Sales', y='Profit')
plt.title('Scatter Plot of Sales and Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# Observations:
# 1. From This `Fig 1` There is Relationship between Sales and Profits.
# 2. The Highest Prfits Is cross `8000` and Sales Also Highest `9000` . But its not Enough Its maybe Outlier , see Furthur.
# 3. Mostly Orders Range in `0 To 2000.`

# %% [markdown]
# # __`📊 Assumptions 📊 `__

# %% [markdown]
#  ## __`Question No 1: 📊 How are the sales and profit related? Are there any trends?`__

# %%
# Create a scatter plot with a regression line using Seaborn
plt.figure(figsize=(18, 6))
sns.regplot(data=df, x='Sales', y='Profit', color= 'Green',scatter_kws={"alpha":0.5})
plt.title('Scatter Plot of Sales vs. Profit with Trend Line')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# Insight:
# 01. Yes In this Plot There is A `Strong Positive Trend` .

# %% [markdown]
# ## __`Question No 02: 🌐 Is there a relationship between regions and sales?`__

# %%
# Create a count plot to visualize sales distribution by region
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='Region', order= df['Region'].value_counts().index, palette='Set1')
plt.title('Sales Distribution by Region')
plt.xlabel('Region')
plt.ylabel('Count of Sales')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### __Insight:__
#  - 📈 The "West region" consistently leads in sales, demonstrating its robust market presence and high-performance.
#
# - 📊 In contrast, the "South region" experiences lower sales. This presents an opportunity for analysis and improvement.
# Focusing on the South 🧐 region's unique challenges and customer needs may lead to increased sales, eventually boosting order volume and overall performance.

# %% [markdown]
# ## __`Question No 03: 📆 How do sales and profit change over time?`__

# %%
# Create a time series plot to visualize sales and profit over time
plt.figure(figsize=(18, 6))

sns.lineplot(data=df, x='Order Date', y='Profit', label='Profit')
sns.lineplot(data=df, x='Order Date', y='Sales', label='Sales')
plt.title('Sales and Profit Over Time')
plt.xlabel('Order Date')
plt.ylabel('Value')
plt.legend()
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### __Insight:__
# - The highest profit was achieved in `October 2019`, reaching its peak 📈.
# - However, there was a loss in December 2019, representing the lowest point 📉.
# - `My analysis suggests that while sales were high, the profit margin approached the average level`.

# %% [markdown]
# ## __`Question No 04: 🚚 Is there a correlation between shipping mode and returns?`__

# %%
# Create a count plot to visualize the correlation between shipping mode and returns
plt.figure(figsize=(18, 6))
sns.countplot(data=df, x='Ship Mode', hue='Returns', palette='Set2')
plt.title('Correlation Between Shipping Mode and Returns')
plt.xlabel('Ship Mode')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# __Insight:__
# - 🚚 Shipping modes "First Class" and "Standard Class" exhibit a relatively higher return rate when compared to "Second  Class" and "Same Day."
#
# - 📦 Customers at a higher rate tend to return products when they choose the "Standard Class" shipping option as compared to other modes.
#
# - 💡 My analysis suggests a correlation between shipping modes and returns, highlighting the need for further investigation and improvement in the shipping and delivery processes.

# %% [markdown]
# ## __`Question No 05: 📈 How does the quantity of products affect profit?`__

# %%
# Create a line chart to analyze the impact of product quantity on profit
plt.figure(figsize=(18, 6))
sns.lineplot(data=df, x='Quantity', y='Profit')
plt.title('Effect of Product Quantity on Profit')
plt.xlabel('Quantity')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# __Insight:__
# - 📈 Quantity significantly influences profit.
# - 💰 Profit peaks at quantities range  of` 12-14`.
# - 💡 Recommend increasing quantity for higher sales and profit, but conduct further analysis considering product profitability and customer purchasing power.

# %% [markdown]
# ## __`Question No 06: 🛒 Are there seasonal trends in sales data?`__

# %%
import statsmodels.api as sm
# Perform seasonal decomposition of sales data
decomposition = sm.tsa.seasonal_decompose(df['Sales'], model='additive', period=12)

# Create a seasonal decomposition plot with Seaborn
plt.figure(figsize=(18, 6))
sns.set_style("whitegrid")  # Optional: Set Seaborn style
sns.lineplot(data=decomposition.seasonal, label='Seasonal')
sns.lineplot(data=decomposition.trend, label='Trend')
sns.lineplot(data=decomposition.resid, label='Residuals')
plt.title('Seasonal Decomposition of Sales Data')
plt.xlabel('Time')
plt.legend()
plt.show()

# %% [markdown]
# ### __Insight:__
# - ❌ No apparent seasonal trend evident in the seasonal decomposition plot.
# - 📊 Sales data appears to have significant variability and noise.
# - 🧐 Further analysis required to identify specific patterns or seasonal trends.
# - 🚀 Insights from additional analysis may help in implementing effective strategies for sales improvement.-

# %% [markdown]
# ## __`Question no 07:🧾 What's the most common payment mode for orders?`__

# %%
# Calculate the count of each payment mode
payment_mode_counts = df['Payment Mode'].value_counts()

# Create a pie plot to visualize the most common payment mode
plt.figure(figsize=(20, 6))
sns.set_palette('Set2')
plt.pie(payment_mode_counts, labels=payment_mode_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Most Common Payment Mode for Orders')
plt.show()

# %% [markdown]
#  ### __Insights:__
#  - 💳 Cards were used for approximately 21.8% of orders.
# - 🌐 Online payment methods were preferred in 36.7% of cases.
# - 💰 Cash on Delivery (COD) was the most common payment mode, accounting for 41.6% of orders.
# - 💡 Suggestion: Considering the prevalence of Cash on Delivery (COD), there may be an opportunity to incentivize and promote online payment methods to reduce COD usage and
#  potentially improve efficiency and security in the payment process.

# %% [markdown]
# ## __`Question No 08: 🏙️ Top 10  cities have the highest ?`__

# %%
# Sort the cities by sales in descending order
city_sales_sorted = df.groupby('City')['Sales'].sum().reset_index()
city_sales_sorted = city_sales_sorted.sort_values(by='Sales', ascending=False)

# Select the top 10 cities with the highest sales
top_10_cities = city_sales_sorted.head(10)

# Create a line plot for the top 10 cities with the highest sales
plt.figure(figsize=(18, 6))
sns.lineplot(data=top_10_cities, x='City', y='Sales')
plt.title('Top 10 Cities with Highest Sales')
plt.xlabel('City')
plt.ylabel('Sales')
plt.xticks(rotation=45)  # Rotate city names for better visibility
plt.show()

# %% [markdown]
# ## __Insight:__
# - 🌆 The top 10 cities with the highest sales are led by `New York` City, followed by Los Angeles and `San Francisco.`
# Recommendation:
#
# - 🚀 Consider focusing resources and strategies on these `high-performing cities` to further boost sales and market presence.

# %% [markdown]
# ## __`Question No 09: 📚 Are there any trends in product names that generate high sales?`__

# %%
# Calculate total sales by product name
product_sales = df.groupby('Product Name')['Sales'].sum().reset_index()

# Sort the products by sales in descending order
product_sales_sorted = product_sales.sort_values(by='Sales', ascending=False)

# Select the top 10 products with the highest sales
top_10_products = product_sales_sorted.head(10)

# Create a bar plot to visualize the top 10 products with the highest sales
plt.figure(figsize=(16, 6))
sns.barplot(data=top_10_products, x='Sales', y='Product Name', palette='viridis')
plt.title('Top 10 Products with Highest Sales')
plt.xlabel('Sales')
plt.ylabel('Product Name')
plt.show()

# %% [markdown]
# __Insight:__
#
# - 🖨️ High sales are achieved by a mix of office equipment, such as `printers, copiers, and binding systems`, along with technology products like the `"Samsung Galaxy Mega 6.3."`
#
# - 📈 The top-performing products represent diverse categories, suggesting a range of customer preferences and needs contributing to their success

# %% [markdown]
# ## __` Question 10:🧾 What's the distribution of payment modes for each category?`__

# %%
# Create a bar plot to visualize the distribution of payment modes for each category
plt.figure(figsize=(18, 5))
sns.countplot(data=df, x='Category', hue='Payment Mode', palette='Set1')
plt.title('Distribution of Payment Modes for Each Category')
plt.xlabel('Category')
plt.ylabel('Count')
plt.legend(title='Payment Mode', loc='upper right')
plt.show()

# %% [markdown]
# ## __`Question 11: 📅 How do sales vary by order date?`__

# %%
# Convert the 'Order Date' column to a datetime data type
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Calculate total sales by order date
sales_by_date = df.groupby('Order Date')['Sales'].sum().reset_index()

# Create a time series plot for sales by order date
plt.figure(figsize=(18, 6))
sns.lineplot(data=sales_by_date, x='Order Date', y='Sales')
plt.title('Sales Variation by Order Date (Time Series)')
plt.xlabel('Order Date')
plt.ylabel('Total Sales')
plt.xticks(rotation=45)  # Rotate date labels for better visibility
plt.show()

# %% [markdown]
# __Insight:__
# - The Highest sale Variations In `2020-8` to `2021-01`.

# %% [markdown]
# ## __`Question No 11: 📈 Is there a correlation between the number of products ordered and returns?`__

# %%
# Create a scatter plot to visualize the correlation
plt.figure(figsize=(18, 4))
sns.scatterplot(data=df, x='Quantity', y='Returns', hue='Returns', palette='viridis')
plt.title('Correlation Between Number of Products Ordered and Returns')
plt.xlabel('Number of Products Ordered')
plt.ylabel('Returns (0: No, 1: Yes)')
plt.show()

# %% [markdown]
# __Insight:__
# - There Is no `Corelationship` Each Other.

# %% [markdown]
# ## __` Question 12: 📈 How does the quantity of products purchased change over time? `__

# %%
# Convert the 'Order Date' column to a datetime data type
df['Order Date'] = pd.to_datetime(df['Order Date'])

# Calculate total quantity by order date
quantity_by_date = df.groupby('Order Date')['Quantity'].sum().reset_index()

# Create a time series plot for quantity by order date with customizations
plt.figure(figsize=(18, 6))
sns.set(style="whitegrid")  # Set the style
sns.lineplot(data=quantity_by_date, x='Order Date', y='Quantity', color='blue')  # Change line color
plt.title('Quantity of Products Purchased Over Time (Time Series)', fontsize=16, color='green')  # Change title font size and color
plt.xlabel('Order Date', fontsize=12, color='purple')  # Change x-axis label font size and color
plt.ylabel('Total Quantity', fontsize=12, color='orange')  # Change y-axis label font size and color
plt.xticks(rotation=45)  # Rotate date labels for better visibility
plt.show()

# %% [markdown]
# ## __`Question No 13: 📈 How does profit change over the years? `__

# %%
# Extract the year from the 'Order Date' column
df['Year'] = df['Order Date'].dt.year

# Calculate total profit by year
profit_by_year = df.groupby('Year')['Profit'].sum().reset_index()

# Create a line chart for profit by year
plt.figure(figsize=(18, 6))
sns.lineplot(x='Year', y='Profit', data=profit_by_year)
plt.title('Profit Variation Over the Years (Line Chart)')
plt.xlabel('Year')
plt.ylabel('Total Profit')
plt.show()
